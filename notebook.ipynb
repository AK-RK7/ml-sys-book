# %%
import pandas as pd

df = pd.read_csv(
    "data/rag_evaluation_results.csv"
)

print(
    df[df["relevance"]=="NON_RELEVANT"]
    [
        [
            "question",
            "answer",
            "sources",
            "relevance_explanation"
        ]
    ]
    .head(20)
)
# Out:
#                                               question  \
# 7    Who coined the term "memory wall" and in what ...
# 18   How many GPUs are used in Scenario 2 for the 3...
# 19   What label is assigned to the x-axis in the plot?
# 23   According to the passage, what appears only as...
# 26   According to the passage, when do data lakes e...
# 29   What formula is used to calculate ca_cpu_image...
# 39   Which machine learning category has a coordina...
# 56   How is scaling_tax calculated according to the...
# 61   What are the three optimization steps describe...
# 62   According to the passage, how much accuracy ga...
# 66   What was the reported context window size limi...
# 69   What three weight values are typically used in...
# 75   According to the passage, how much CO₂ is embo...
# 81   According to the passage, what is the approxim...
# 95   How is the variable `savings` computed in the ...
# 97   How many nodes are defined with a red fill (my...
# ...
